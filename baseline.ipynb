# %%
# !pip install pandas scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\abdel\miniconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: scikit-learn in c:\users\abdel\miniconda3\lib\site-packages (1.7.0)
# Requirement already satisfied: matplotlib in c:\users\abdel\miniconda3\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\abdel\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\abdel\miniconda3\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abdel\miniconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\abdel\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\abdel\miniconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\abdel\miniconda3\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abdel\miniconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdel\miniconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdel\miniconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdel\miniconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abdel\miniconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdel\miniconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\abdel\miniconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\abdel\miniconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\abdel\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load sample dataset (temporary)
data = fetch_20newsgroups(subset="all", categories=["rec.autos", "sci.med"])

texts = data.data
labels = data.target

# Split
X_train, X_test, y_train, y_test = train_test_split(
    texts, labels, test_size=0.2, random_state=42
)

# TF-IDF
vectorizer = TfidfVectorizer(stop_words="english", max_features=5000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_tfidf, y_train)

# Predict
y_pred = model.predict(X_test_tfidf)

# Result
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.98989898989899

# %%
|
